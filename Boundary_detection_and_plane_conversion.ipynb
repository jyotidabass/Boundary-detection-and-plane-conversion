# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotidabass/Boundary-detection-and-plane-conversion/blob/main/Boundary_detection_and_plane_conversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import cv2 as cv   
 from google.colab.patches import cv2_imshow
 img = cv.imread('/content/140831075759_st.png') #mentioning a path of an image
 cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=809x839 at 0x7F493116D6D0>

# %%
# Python program to read image
# as YCrCb color space
from google.colab.patches import cv2_imshow  

# Import cv2 module
import cv2
  
# Reads the image
img = cv2.imread('/content/140831075759_st.png')
  
# Convert to YCrCb color space
img = cv2.cvtColor(img, cv2.COLOR_BGR2YCrCb)
  
# Shows the image
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=809x839 at 0x7F49329D2FD0>

# %%
# Importing cv2 module
import cv2
  
# Reads the image
img = cv2.imread('/content/140831075759_st.png')
  
# Converts to HSV color space
img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
  
# Shows the image
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=809x839 at 0x7F4931160410>

# %%
# Python program to read image
# as LAB color space
  
# Importing cv2 module
import cv2
  
# Reads the image
img = cv2.imread('/content/140831075759_st.png')
  
# Converts to LAB color space
img = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
  
# Shows the image
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=809x839 at 0x7F49329D2690>

# %%
# Python program to read image
# as EdgeMap
  
# Importing cv2 module
import cv2
  
# Reads the image
img = cv2.imread('/content/140831075759_st.png')
  
  
laplacian = cv2.Laplacian(img, cv2.CV_64F)
cv2_imshow(laplacian)
# Out:
# <PIL.Image.Image image mode=RGB size=809x839 at 0x7F4931177290>
